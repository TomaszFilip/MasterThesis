# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV
df = pd.read_csv('normal_yolo.csv')  # Replace with your actual file path

# Compute FPR
df['FPR'] = df['accident_count'] / df['total_count']
df['A'] = df['A'] / 10

# Plot FPR vs A
plt.figure(figsize=(10, 6))
plt.plot(df['A'], df['FPR'], label='yolo11m', color='blue', marker='o')

# Plot formatting
plt.xlabel('a')
plt.ylabel('FPR')
plt.title('Acceleration FPR (a)')
plt.grid(True)

plt.tight_layout()

df = pd.read_csv('normal_maskrcnn.csv')  # Replace with your actual file path

# Compute FPR
df['FPR'] = df['accident_count'] / df['total_count']
df['A'] = df['A'] / 10

plt.plot(df['A'], df['FPR'], label='Mask R-CNN', color='darkorange', marker='x')
plt.legend()
# Save plot
plt.savefig('fpr_plot_yolo.png', dpi=300)  # Saves the figure as 'fpr_plot.png'

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV
df = pd.read_csv('accident_yolo.csv')  # Replace with your actual file path

# Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']
df['A'] = df['A'] / 10

# Plot FPR vs A
plt.figure(figsize=(10, 6))
plt.plot(df['A'], df['TPR'], label='yolo11m', color='blue', marker='o')

# Load CSV
df = pd.read_csv('accident_maskrcnn.csv')  # Replace with your actual file path

# Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']
df['A'] = df['A'] / 10

plt.plot(df['A'], df['TPR'], label='Mask R-CNN', color='darkorange', marker='x')

# Plot formatting
plt.xlabel('a')
plt.ylabel('TPR')
plt.title('Acceleration TPR(a)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Save plot
plt.savefig('tpr_plot_yolo.png', dpi=300)  # Saves the figure as 'fpr_plot.png'

# Show plot
plt.show()

# %%
# Load CSV
df = pd.read_csv('normal_yolo_G.csv')  # Replace with your actual file path

#Compute FPR
df['FPR'] = df['accident_count'] / df['total_count']#df['A'] = df['A'] / 10

plt.figure(figsize=(10, 6))
plt.plot(df['G']/10, df['FPR'], label='yolo11m', color='blue', marker='o')

# Plot formatting
plt.xlabel('a')
plt.ylabel('FPR')
plt.title('Angle FPR(g)')
plt.grid(True)

plt.tight_layout()

df = pd.read_csv('normal_maskrcnn_G.csv')  # Replace with your actual file path

# Compute FPR
df['FPR'] = df['accident_count'] / df['total_count']
df['G'] = df['G'] / 10

plt.plot(df['G'], df['FPR'], label='Mask R-CNN', color='darkorange', marker='x')
plt.legend()
# Save plot
plt.savefig('fpr_plot_yolo.png', dpi=300)  # Saves the figure as 'fpr_plot.png'

# Show plot
plt.show()

# %%
# Load CSV
df = pd.read_csv('accident_yolo_G.csv')  # Replace with your actual file path

#Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']#df['A'] = df['A'] / 10

plt.figure(figsize=(10, 6))
plt.plot(df['G']/10, df['TPR'], label='yolo11m', color='blue', marker='o')

# Plot formatting
plt.xlabel('a')
plt.ylabel('TPR')
plt.title('Angle TPR (g)')
plt.grid(True)

plt.tight_layout()

df = pd.read_csv('accident_maskrcnn_G.csv')  # Replace with your actual file path
print(df)

# Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']
df['G'] = df['G'] / 10

plt.plot(df['G'], df['TPR'], label='Mask R-CNN', color='darkorange', marker='x')
plt.legend()
# Save plot
plt.savefig('tpr_plot_G.png', dpi=300)  # Saves the figure as 'fpr_plot.png'

# Show plot
plt.show()
# Out:
#     A  total_count  accident_count  B   G
# 0   0           15               0  0   0
# 1   0           15               0  0   1
# 2   0           15               0  0   2
# 3   0           15               0  0   3
# 4   0           15              13  0   4
# 5   0           15              13  0   5
# 6   0           15              13  0   6
# 7   0           15              13  0   7
# 8   0           15              13  0   8
# 9   0           15              13  0   9
# 10  0           15              13  0  10
# 11  0           15              13  0  11
# 12  0           15              13  0  12
# 13  0           15              13  0  13
# 14  0           15              13  0  14
# 15  0           15              13  0  15
# 16  0           15              13  0  16
# 17  0           15              13  0  17
# 18  0           15              13  0  18
# 19  0           15              13  0  19

# %%
# Load CSV
df = pd.read_csv('accident_yolo_B.csv')  # Replace with your actual file path

#Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']#df['A'] = df['A'] / 10

plt.figure(figsize=(10, 6))
plt.plot(df['B'], df['accident_count'], label='yolo11m', color='blue', marker='o')

# Plot formatting
plt.xlabel('a')
plt.ylabel('TPR')
plt.title('Accidents(β)')
plt.grid(True)

plt.tight_layout()

df = pd.read_csv('accident_maskrcnn_B.csv')  # Replace with your actual file path
print(df)

# Compute FPR
df['TPR'] = df['accident_count'] / df['total_count']
df['accident_count'] = df['accident_count']

plt.plot(df['B'], df['accident_count'], label='Mask R-CNN', color='darkorange', marker='x')
plt.legend()
# Save plot
plt.savefig('plot_B.png', dpi=300)  # Saves the figure as 'fpr_plot.png'

# Show plot
plt.show()
# Out:
#    A  total_count  accident_count    B  G
# 0  7           15              11  1.0  4
# 1  7           15              10  2.0  4
# 2  7           15              11  3.0  4
# 3  7           15              11  4.0  4
